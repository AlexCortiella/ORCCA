# %%
import os
from ultralytics import YOLO
import numpy as np
from PIL import Image
import requests
from io import BytesIO
import cv2


import matplotlib.pyplot as plt
import matplotlib.patches as patches

import torch
from torchvision.utils import make_grid
from torchvision.io import read_image
from torchvision import datasets, transforms
import torchvision.transforms.functional as F
import matplotlib.image as mpimg
# Out:
# /usr/lib/python3/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/usr/lib/python3/dist-packages/torchvision/image.so: undefined symbol: _ZN3c104cuda20CUDACachingAllocator9allocatorE'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
# def plot_bboxes(image, boxes):
#     xpix, ypix, chan = image.shape
#     #plot each boxes
#     for box in boxes:
#         lw = max(round(sum(image.shape) / 2 * 0.003), 2)
#         p1, p2 = (int(box[0]*xpix), int(box[1]*ypix)), (int(box[2]*xpix), int(box[3]*ypix))
#         cv2.rectangle(image, p1, p2, color=(0,255,0), thickness=lw, lineType=cv2.LINE_AA)

#     #show image
#     cv2.imshow('image',image) #if used in Python
    
def plot_bboxes(image, boxes, normalized = True):
    
    # Create figure and axes
    fig, ax = plt.subplots()
    # Display the image
    ax.imshow(image)
        
    #plot each boxes
    for box in boxes:
        lw = max(round(sum(image.shape) / 2 * 0.003), 2)
        #cxy = (int(box[0]*xpix), int(box[1]*ypix))
        if normalized:
            xpix, ypix, chan = image.shape
            width, height = (int(box[2]*xpix), int(box[3]*ypix))
            xy = (int(box[0]*xpix - 0.5*width), int(box[1]*ypix - 0.5*height))
        else:
            width, height = (box[2], box[3])
            xy = (box[0]- 0.5*width, box[1] - 0.5*height)
        # Create a Rectangle patch
        rect = patches.Rectangle(xy, width, height, linewidth=lw, edgecolor='g', facecolor='none')
        # Add the patch to the Axes
        ax.add_patch(rect)
    #show image
    plt.show()

# %%
data_dir = './data/mars_rover/train'
img_dir = os.path.join(data_dir, 'images')
lbl_dir = os.path.join(data_dir, 'labels')

img_namelist = os.listdir(img_dir)
img_namelist.sort()
lbl_namelist = os.listdir(lbl_dir)
lbl_namelist.sort()

img_list = []
lbl_list = []
box_list = []

for img_name in img_namelist:
    
    # Using readlines()
    name = os.path.splitext(img_name)[0]
    print(f'Processing image: {name}')
    lbls = open(os.path.join(lbl_dir,name + '.txt'), 'r')
    lines = lbls.readlines()
    llst = []
    blst = []
    for line in lines:
        
        line = line.split('\n')[0]
        line = line.split(' ')
        line = [float(item) for item in line]
        if line[0] == 0.0:#rock class
            llst.append(str(int(line[0])))
            blst.append(line[1:])
    lbl_list.append(llst)
    box_list.append(blst)
    img = mpimg.imread(os.path.join(img_dir,img_name))
    img_list.append(img)
# Out:
# Processing image: HX1-Ro_GRAS_20210605105425_png_jpg.rf.72db1008886d9162528a17f904a4b08f
# Processing image: HX1-Ro_GRAS_20210605105425_png_jpg.rf.796579c7273866c74ebbe74eab7109eb
# Processing image: HX1-Ro_GRAS_20210605105425_png_jpg.rf.b2fdbb3618c60e60704ec5c074acba5d
# Processing image: HX1-Ro_GRAS_20210605105425_png_jpg.rf.d53887872db7cfece135ca3d3db85f21
# Processing image: HX1-Ro_GRAS_20210606113032_png_jpg.rf.074901e3f8e9cb9dde3502b65b485bbe
# Processing image: HX1-Ro_GRAS_20210606113032_png_jpg.rf.135b25743f2771993f28d5eacd13047e
# Processing image: HX1-Ro_GRAS_20210606113032_png_jpg.rf.1a8890dd24d373ea26217bd48eb9b407
# Processing image: HX1-Ro_GRAS_20210606113032_png_jpg.rf.229b074d2061658421abb7b8f1de5d48
# Processing image: HX1-Ro_GRAS_20210606113032_png_jpg.rf.67718e314dd075798c03fd4e31fa756e
# Processing image: HX1-Ro_GRAS_20210606113032_png_jpg.rf.7313564b6ff33b2e01a864d316ab1db2
# Processing image: HX1-Ro_GRAS_20210606113032_png_jpg.rf.8bdf3479c054eedc250ce91cfa758554
# Processing image: HX1-Ro_GRAS_20210606113032_png_jpg.rf.ca2375f4e954ea3afa0733f73917a30c
# Processing image: HX1-Ro_GRAS_20210606113032_png_jpg.rf.eca96c7985ac04745068ef842bf3df4e
# Processing image: HX1-Ro_GRAS_20210606113342_png_jpg.rf.0af0daeca3295798e4fa5eddb4561f90
# Processing image: HX1-Ro_GRAS_20210606113342_png_jpg.rf.0c6d83d374536b10696147cdfae4633c
# Processing image: HX1-Ro_GRAS_20210606113342_png_jpg.rf.103ff67867484c64d974bce33c4ba51a
# Processing image: HX1-Ro_GRAS_20210606113342_png_jpg.rf.209399aed8b3f3751b6b6e6acbd9c2cc
# Processing image: HX1-Ro_GRAS_20210606113342_png_jpg.rf.60b013278c07c98bdfbb5b3ab66918c2
# Processing image: HX1-Ro_GRAS_20210606113342_png_jpg.rf.6a39c2667f0e4389999f7a8bbda3da69
# Processing image: HX1-Ro_GRAS_20210606113342_png_jpg.rf.83bbb1a417cc7430c2ec15ddfe113569
# Processing image: HX1-Ro_GRAS_20210606113342_png_jpg.rf.83f46826bbb5b2e2429338a913bc7fb4
# Processing image: HX1-Ro_GRAS_20210606113342_png_jpg.rf.8c528f3801dcd09818c1a4135cd52e96
# Processing image: HX1-Ro_GRAS_20210606113342_png_jpg.rf.bac0b5b0177966e51cbc10f8fd3b5844
# Processing image: HX1-Ro_GRAS_20210606113342_png_jpg.rf.d113639e8067b54347f4d324b0ee7442
# Processing image: HX1-Ro_GRAS_20210606113342_png_jpg.rf.e1593a07d2cf837a1b4454d0da7587c8
# Processing image: HX1-Ro_GRAS_20210606113342_png_jpg.rf.eb79d222cad37899c93981bf5019d430
# Processing image: HX1-Ro_GRAS_20210606113342_png_jpg.rf.f7f128f0b623b653426bd7b902128418
# Processing image: HX1-Ro_GRAS_20210607121458_png_jpg.rf.1a840912acfc028af8209500e303f26e
# Processing image: HX1-Ro_GRAS_20210607121458_png_jpg.rf.26e4f69691ce4a9bdece4429c3e70dcc
# Processing image: HX1-Ro_GRAS_20210607121458_png_jpg.rf.4377e7f4a6921bb0d959d263f35ce1f4
# Processing image: HX1-Ro_GRAS_20210607121458_png_jpg.rf.71d2413b504f0fb96376f577c57f7fd1
# Processing image: HX1-Ro_GRAS_20210607121458_png_jpg.rf.9991127eab6f9255d9d4736f314c0cec
# Processing image: HX1-Ro_GRAS_20210607121458_png_jpg.rf.9ac53c9561e3af166a8b7d9159df3d19
# Processing image: HX1-Ro_GRAS_20210607121458_png_jpg.rf.bc0b571701c3a8abbf362016c7df4a00
# Processing image: HX1-Ro_GRAS_20210607121458_png_jpg.rf.bddb2ac8729aa79eaa26315e8bd6c656
# Processing image: HX1-Ro_GRAS_20210607121458_png_jpg.rf.ddab57b7348cf1bf46224b64e38ff55c
# Processing image: HX1-Ro_GRAS_20210607121458_png_jpg.rf.f6ec7d5407f35dcd68b9fae0618a9a3a
# Processing image: HX1-Ro_GRAS_20210607121458_png_jpg.rf.faa7e5c4d368795bda11e21583fa51c2
# Processing image: HX1-Ro_GRAS_20210610141601_png_jpg.rf.72a691bd600b377b4da6679932f48709
# Processing image: HX1-Ro_GRAS_20210610141601_png_jpg.rf.7984b3eb720e9568eff89093310ba3cc
# Processing image: HX1-Ro_GRAS_20210612152619_png_jpg.rf.0cc95e86346e8b2b7adad3eab1e41cdb
# Processing image: HX1-Ro_GRAS_20210612152619_png_jpg.rf.2368555f8c26457bb23ba713027b8d06
# Processing image: HX1-Ro_GRAS_20210612152619_png_jpg.rf.5f80a1e9ec647b66992dde8ae029ed5e
# Processing image: HX1-Ro_GRAS_20210612152619_png_jpg.rf.84539625b7b981ad230b7c73814aaa4d
# Processing image: HX1-Ro_GRAS_20210612152619_png_jpg.rf.aa5baf32b815c89ad0da6ff6879220ae
# Processing image: HX1-Ro_GRAS_20210612152619_png_jpg.rf.b4b781767d89e374c7ea4b5c18554ae7
# Processing image: HX1-Ro_GRAS_20210612152619_png_jpg.rf.bec76e5dc043693bfc3ef9b934c730ef
# Processing image: HX1-Ro_GRAS_20210612152619_png_jpg.rf.c2b0a6f593f9e6f9ec612abdf82129a4
# Processing image: HX1-Ro_GRAS_20210612152619_png_jpg.rf.c8017141e60e4180bed7b4a07998b09e
# Processing image: HX1-Ro_GRAS_20210613161220_png_jpg.rf.49b3dfe197bbe599cb88e20781d12f27
# Processing image: HX1-Ro_GRAS_20210613161220_png_jpg.rf.4d38c5b8e8087030710297d5cabb0161
# Processing image: HX1-Ro_GRAS_20210613161220_png_jpg.rf.5362d872a7e7b4a674e48355b866f228
# Processing image: HX1-Ro_GRAS_20210613161220_png_jpg.rf.606d98f3c5032dea576969577eedc4c0
# Processing image: HX1-Ro_GRAS_20210613161220_png_jpg.rf.9f8c3315572a50804a9c8e707923a195
# Processing image: HX1-Ro_GRAS_20210613161220_png_jpg.rf.e15617a810ab9ce9c01e01f899cf6aa7
# Processing image: HX1-Ro_GRAS_20210614164834_png_jpg.rf.17fd3dcf3251c949e76d4739ac8f59d3
# Processing image: HX1-Ro_GRAS_20210614164834_png_jpg.rf.22790f0df1b8bca4653452fe17667f6e
# Processing image: HX1-Ro_GRAS_20210614164834_png_jpg.rf.3add7f976605d66f86da6f68c4b35934
# Processing image: HX1-Ro_GRAS_20210614164834_png_jpg.rf.5520d0c36b5faab496957783397129ba
# Processing image: HX1-Ro_GRAS_20210614164834_png_jpg.rf.5580c7138df91a2dc3baae5726434b75
# Processing image: HX1-Ro_GRAS_20210614164834_png_jpg.rf.6c01967e832d320840a368ca0f9f8fad
# Processing image: HX1-Ro_GRAS_20210614164834_png_jpg.rf.8b2cf1ad473d4a3a88060172beef1127
# Processing image: HX1-Ro_GRAS_20210614164834_png_jpg.rf.f829e03aba53e9724de7b12bcf1575ad
# Processing image: HX1-Ro_GRAS_20210614165009_png_jpg.rf.034b0b29922a19afb3ac73fa0912cda8
# Processing image: HX1-Ro_GRAS_20210614165009_png_jpg.rf.7a84956002601e19885fadc919dab8b8
# Processing image: HX1-Ro_GRAS_20210614165009_png_jpg.rf.b06984f947509b0e600a953fd7c4fe47
# Processing image: HX1-Ro_GRAS_20210614165009_png_jpg.rf.f9b0e32a793b47f2cc6e72d55aa32d14
# Processing image: HX1-Ro_GRAS_20210614165009_png_jpg.rf.fa1515e58b37b8cb60005c3d0ad690ea
# Processing image: HX1-Ro_GRAS_20210616180332_png_jpg.rf.17167e8bf1997ed4cf91c71a53ca5b2b
# Processing image: HX1-Ro_GRAS_20210616180332_png_jpg.rf.172d212603726c253a58f74c36c1a5e5
# Processing image: HX1-Ro_GRAS_20210616180332_png_jpg.rf.488f28b17092f0b0c16c659540a69093
# Processing image: HX1-Ro_GRAS_20210616180332_png_jpg.rf.50a4d3c2a73e744af12022a684ec7a6b
# Processing image: HX1-Ro_GRAS_20210616180332_png_jpg.rf.b370e66cc1b8d6049f40aa78ab81c48c
# Processing image: HX1-Ro_GRAS_20210616180332_png_jpg.rf.ca1bd6ab5038060d53986fc5132116b4
# Processing image: HX1-Ro_GRAS_20210616180507_png_jpg.rf.6e1579aa88ea384b563d26c3ae18beed
# Processing image: HX1-Ro_GRAS_20210616180507_png_jpg.rf.77685a0f869c646e06636ff9778ebcda
# Processing image: HX1-Ro_GRAS_20210616180507_png_jpg.rf.9fbf18b3f87b0590f28f3d78551d3c62
# Processing image: HX1-Ro_GRAS_20210616180507_png_jpg.rf.b700b8ab7037617cf67d4b399b7be656
# Processing image: HX1-Ro_GRAS_20210616180507_png_jpg.rf.c4cc76bdded205cac6e5de132df2a7bd
# Processing image: HX1-Ro_GRAS_20210616180507_png_jpg.rf.cf26887743f5fc3a51f7a6b4215e957a
# Processing image: HX1-Ro_GRAS_20210616180507_png_jpg.rf.e09a893186e6146a3f1c28ea64b39205
# Processing image: HX1-Ro_GRAS_20210616180507_png_jpg.rf.fb32e03e69925f2d65fc29c781cbdf71
# Processing image: HX1-Ro_GRAS_20210625233319_png_jpg.rf.21b8c9bfe85a52acb9113f84989a25f1
# Processing image: HX1-Ro_GRAS_20210625233319_png_jpg.rf.24463ad215dd989891782a726c14c627
# Processing image: HX1-Ro_GRAS_20210625233319_png_jpg.rf.3bc86c4973d0e68d396d31f2448a34aa
# Processing image: HX1-Ro_GRAS_20210625233319_png_jpg.rf.5143184c7bb08b0a592065f89abc6169
# Processing image: HX1-Ro_GRAS_20210625233319_png_jpg.rf.d9d18c6df8ea4a02ab17f243c58714c9
# Processing image: HX1-Ro_GRAS_20210625233319_png_jpg.rf.f9a2fbc315abbd2f19fd34608fccfdf6
# Processing image: HX1-Ro_GRAS_20210625233319_png_jpg.rf.fff0e6874485418d79c2030a6f083629
# Processing image: HX1-Ro_GRAS_20210628005041_png_jpg.rf.53f8b27cbc1a0304d8509aa5c8a3095c
# Processing image: HX1-Ro_GRAS_20210628005041_png_jpg.rf.a41b3fcc6b6d997651fb7e9180065adf
# Processing image: HX1-Ro_GRAS_20210628005041_png_jpg.rf.b9e22654b1eb981c4baa34b8286bdabb
# Processing image: HX1-Ro_GRAS_20210628005041_png_jpg.rf.e9cdac3b3e76cb8deee4f21fbff9d1dc
# Processing image: HX1-Ro_GRAS_20210629002235_png_jpg.rf.009ae4c254b1d169bce13d85545e64f7
# Processing image: HX1-Ro_GRAS_20210629002235_png_jpg.rf.42c767fff15912dcaa796f7fb5760762
# Processing image: HX1-Ro_GRAS_20210629002235_png_jpg.rf.5c276662794115b436b5a290624f303f
# Processing image: HX1-Ro_GRAS_20210629002235_png_jpg.rf.7baf73978bb95cd463b36435f93ca160
# Processing image: HX1-Ro_GRAS_20210629002235_png_jpg.rf.8cb0717c0f77196493a13b904d13b2a0
# Processing image: HX1-Ro_GRAS_20210629002235_png_jpg.rf.a407295e39289cd28e0dfa1aa5403b2d
# Processing image: HX1-Ro_GRAS_20210629002235_png_jpg.rf.bf6a9538f993be621e3e537aac6bd0e6
# Processing image: HX1-Ro_GRAS_20210629002235_png_jpg.rf.c0656e8606569b0d7d660f0a9df417a5
# Processing image: HX1-Ro_GRAS_20210703033752_png_jpg.rf.0c6062fe43bf4ebadc484965f1f0f0f1
# Processing image: HX1-Ro_GRAS_20210703033752_png_jpg.rf.121d3c943e288e0052c80ef2e1701411
# Processing image: HX1-Ro_GRAS_20210703033752_png_jpg.rf.182a00781edec998a267862792936126
# Processing image: HX1-Ro_GRAS_20210703033752_png_jpg.rf.46465f57f01d46659d0df05ccbcb1455
# Processing image: HX1-Ro_GRAS_20210703033752_png_jpg.rf.57cd3c368266fc72e5c535fd173b531e
# Processing image: HX1-Ro_GRAS_20210703033752_png_jpg.rf.a87003cd67c74f81d2177396f8540e0d
# Processing image: HX1-Ro_GRAS_20210703033752_png_jpg.rf.fef1e21e746d7e002294ecaae031a8a2
# Processing image: HX1-Ro_GRAS_20210710074231_png_jpg.rf.1ba17fc5ce131e9b647d7e6a96f3bed8
# Processing image: HX1-Ro_GRAS_20210710074231_png_jpg.rf.25b2398b825cc8f8ca606f707877e709
# Processing image: HX1-Ro_GRAS_20210710074231_png_jpg.rf.39cf1a369ef533759e597f605a701586
# Processing image: HX1-Ro_GRAS_20210710074231_png_jpg.rf.7e98e0a78de59fa6214c3d1537a7394a
# Processing image: HX1-Ro_GRAS_20210710074231_png_jpg.rf.da9548f04dba87584663a7c94e7aeee9
# Processing image: HX1-Ro_GRAS_20210710074231_png_jpg.rf.f077873d5f2dff370a4282c640b9c6f3
# Processing image: HX1-Ro_GRAS_20210711082153_png_jpg.rf.0bede2d931670036194b7ad1f6715cac
# Processing image: HX1-Ro_GRAS_20210711082153_png_jpg.rf.6288e25650350068357c1da040375e0b
# Processing image: HX1-Ro_GRAS_20210711082153_png_jpg.rf.9f982dc0be64d7728212d28972c08fa0
# Processing image: HX1-Ro_GRAS_20210711082153_png_jpg.rf.bddda992c01154ac6af950e4b9058090
# Processing image: HX1-Ro_GRAS_20210711082153_png_jpg.rf.be65de9b06482bc70151edfd419d31c5
# Processing image: HX1-Ro_GRAS_20210711082153_png_jpg.rf.cb18f1e93b116f2cf6e4ffe7a8313c89
# Processing image: HX1-Ro_GRAS_20210717122132_png_jpg.rf.29cdd054f3d0562ee50cb5c0cc386b4e
# Processing image: HX1-Ro_GRAS_20210717122132_png_jpg.rf.345901112775126b8e91cd6705907b7c
# Processing image: HX1-Ro_GRAS_20210717122132_png_jpg.rf.351f02d5d38ba4dc054d53367fba01f6
# Processing image: HX1-Ro_GRAS_20210717122132_png_jpg.rf.5fe3ba5517fd9f31c550674be9f9079e
# Processing image: HX1-Ro_GRAS_20210717122132_png_jpg.rf.6b0ff285bd6472a2cebfc800566c19fe
# Processing image: HX1-Ro_GRAS_20210717122132_png_jpg.rf.6dd496af4763e2a9a89c057a8482d98d
# Processing image: HX1-Ro_GRAS_20210717122132_png_jpg.rf.e08ce5f342b33c957979e3d457628b16
# Processing image: HX1-Ro_GRAS_20210717122132_png_jpg.rf.e98c89c793be244b3c52b17b29ccd743
# Processing image: HX1-Ro_GRAS_20210721145553_png_jpg.rf.423ae4c7e69d0045f5f8b2cfac6903cf
# Processing image: HX1-Ro_GRAS_20210721145553_png_jpg.rf.4f940a679208fdca9f2e0c7f6f55930b
# Processing image: HX1-Ro_GRAS_20210721145553_png_jpg.rf.5afea799a50fa5157f35f66337d3d223
# Processing image: HX1-Ro_GRAS_20210721145553_png_jpg.rf.60c755c46f226072229ce8adc45487f6
# Processing image: HX1-Ro_GRAS_20210721145553_png_jpg.rf.9d94c6676193df84c34ea14695ecb2ef
# Processing image: HX1-Ro_GRAS_20210721145553_png_jpg.rf.a51bd23f0119007f8d64997c0b0007c8
# Processing image: HX1-Ro_GRAS_20210721145553_png_jpg.rf.dc986cb285afe7a48d0f1cd1bbf117f4
# Processing image: HX1-Ro_GRAS_20210721145553_png_jpg.rf.e13a3c252f8bd14658a84ad44a8ed968
# Processing image: HX1-Ro_GRAS_20210721145711_png_jpg.rf.16533f9ab1bcce098af305ffe208705c
# Processing image: HX1-Ro_GRAS_20210721145711_png_jpg.rf.421b2bb754aa247be112297d9318c314
# Processing image: HX1-Ro_GRAS_20210721145711_png_jpg.rf.47119f87291b59b47359115fb045ec17
# Processing image: HX1-Ro_GRAS_20210721145711_png_jpg.rf.84565b8db01105ff6531f823b83da24b
# Processing image: HX1-Ro_GRAS_20210721145711_png_jpg.rf.9be6fc36538bf5578cd95010a85a18cc
# Processing image: HX1-Ro_GRAS_20210721145711_png_jpg.rf.cfe8a138cdf54429618906104d56b0b5
# Processing image: HX1-Ro_GRAS_20210721145711_png_jpg.rf.eab5eb98a476f4eba677e525690a9046
# Processing image: HX1-Ro_GRAS_20210722154515_png_jpg.rf.0183efc1f56d96ecbfecf299c8b8984e
# Processing image: HX1-Ro_GRAS_20210722154515_png_jpg.rf.12444d87cc336bd1c911c51671010ab5
# Processing image: HX1-Ro_GRAS_20210722154515_png_jpg.rf.2bb4103796ab813bde25ee6c3db513d5
# Processing image: HX1-Ro_GRAS_20210722154515_png_jpg.rf.6647bb167caa1c50cb0ca55b463a0f4d
# Processing image: HX1-Ro_GRAS_20210722154515_png_jpg.rf.ddf4e644d1af78ae8a200f31e461b458
# Processing image: HX1-Ro_GRAS_20210722154515_png_jpg.rf.ed613e17f5f529f48523eb51827ec941
# Processing image: HX1-Ro_GRAS_20210723154755_png_jpg.rf.0430a71a7b10fa925a296dabe97837ce
# Processing image: HX1-Ro_GRAS_20210723154755_png_jpg.rf.0605cfd9605b827cd6c0677ab3174f4c
# Processing image: HX1-Ro_GRAS_20210723154755_png_jpg.rf.1099f3f3703dc34e5d9df8a781197743
# Processing image: HX1-Ro_GRAS_20210723154755_png_jpg.rf.69cd45834274362d464f91687d40c383
# Processing image: HX1-Ro_GRAS_20210725173134_png_jpg.rf.5953ce82ab40ad4a4cc6af604b1193bd
# Processing image: HX1-Ro_GRAS_20210725173134_png_jpg.rf.6d8ac87975f9ca66f02657f7d4a5d687
# Processing image: HX1-Ro_GRAS_20210725173134_png_jpg.rf.73d4f5eed3d4e9dec7961b33b6a36004
# Processing image: HX1-Ro_GRAS_20210725173134_png_jpg.rf.7692a8c0d4703845098489b13198f2fd
# Processing image: HX1-Ro_GRAS_20210725173134_png_jpg.rf.8bf007f43767f5a14adb54eb6385517d
# Processing image: HX1-Ro_GRAS_20210725173134_png_jpg.rf.bbef8782c9bfd77d0f03d70f959045d2
# Processing image: HX1-Ro_GRAS_20210725173134_png_jpg.rf.dbde26f08e2512ffe0e30ce514a1fece
# Processing image: HX1-Ro_GRAS_20210725173309_png_jpg.rf.447569d98a3515ea7fb91a6a18cde0ec
# Processing image: HX1-Ro_GRAS_20210725173309_png_jpg.rf.5e9866e4d2b9bef4b592b69f645fb080
# Processing image: HX1-Ro_GRAS_20210725173309_png_jpg.rf.6a3971dc4f966fddf592d3174d608bf2
# Processing image: HX1-Ro_GRAS_20210725173309_png_jpg.rf.765298b205d4911346fc19a5cfcd5e21
# Processing image: HX1-Ro_GRAS_20210725173309_png_jpg.rf.8d08ac08bb79cd4428528084d0b2a359
# Processing image: HX1-Ro_GRAS_20210725173309_png_jpg.rf.a25e6303efdcfd708936bef582bb71f0
# Processing image: HX1-Ro_GRAS_20210725173309_png_jpg.rf.abd3b3d0822ce9cd88bc29e46ba7da4f
# Processing image: HX1-Ro_GRAS_20210725173309_png_jpg.rf.da8b9ffcb9d1c674960eec5f8aecd1b0
# Processing image: HX1-Ro_GRAS_20210725173309_png_jpg.rf.faefa6f6dd01aa82d8b798ce3cdc5dc9
# Processing image: HX1-Ro_GRAS_20210725173444_png_jpg.rf.0b77ae946ff2987e48abb4827fab82b3
# Processing image: HX1-Ro_GRAS_20210725173444_png_jpg.rf.1c435fcffd80265c2e00c56c61e566aa
# Processing image: HX1-Ro_GRAS_20210725173444_png_jpg.rf.44682b1a4f97d14413c8ab700ced27d0
# Processing image: HX1-Ro_GRAS_20210725173444_png_jpg.rf.70c91201ffd8e5a53d51625f58cf3309
# Processing image: HX1-Ro_GRAS_20210725173444_png_jpg.rf.94896d4a4d776a81871087053578eb1c
# Processing image: HX1-Ro_GRAS_20210725173444_png_jpg.rf.ce32cc1ab6dc5be06f7a424906416ce3
# Processing image: HX1-Ro_GRAS_20210725173444_png_jpg.rf.f49799735d6ba27838f57121406f9ad7
# Processing image: HX1-Ro_GRAS_20210727184822_png_jpg.rf.4be667460b8892658975e89ef171d278
# Processing image: HX1-Ro_GRAS_20210727184822_png_jpg.rf.5a1773645f0512cf15d17b2ac8e1cb95
# Processing image: HX1-Ro_GRAS_20210727184822_png_jpg.rf.5f78e98c91f7e8ffa1eb2bee0524601f
# Processing image: HX1-Ro_GRAS_20210727184822_png_jpg.rf.66bde22832f0d0778417e0f15b7eafe1
# Processing image: HX1-Ro_GRAS_20210727184822_png_jpg.rf.a468da0886649da8b26759f61733089d
# Processing image: HX1-Ro_GRAS_20210727184822_png_jpg.rf.bf5c1a9174b00e54ce270b84ed3fa40b
# Processing image: HX1-Ro_GRAS_20210727184822_png_jpg.rf.d86f7762051c50afe0c480b752b317f8
# Processing image: HX1-Ro_GRAS_20210727184957_png_jpg.rf.217c29abb6b2bdb2e009f56acbf342ee
# Processing image: HX1-Ro_GRAS_20210727184957_png_jpg.rf.24045659783fb61b7518440f525d763d
# Processing image: HX1-Ro_GRAS_20210727184957_png_jpg.rf.4d6b2d5fffa2827e3b863e5c4a6d3497
# Processing image: HX1-Ro_GRAS_20210727184957_png_jpg.rf.df088bb05ae2106578c460fad92cdf53
# Processing image: HX1-Ro_GRAS_20210727184957_png_jpg.rf.eaa8fc4cc8ba304aa014af3323740ced
# Processing image: HX1-Ro_GRAS_20210727185149_png_jpg.rf.2ecabf40445cd0f5626e17b3569e1baa
# Processing image: HX1-Ro_GRAS_20210727185149_png_jpg.rf.40af589cfa1710c77a2623d7fe677438
# Processing image: HX1-Ro_GRAS_20210727185149_png_jpg.rf.515f7b1c100f6e9b6cbbc2e51a8d0b46
# Processing image: HX1-Ro_GRAS_20210727185149_png_jpg.rf.72dc970081d8bb1d545b40596fa54b4a
# Processing image: HX1-Ro_GRAS_20210727185149_png_jpg.rf.8b2e934530bd7cc9a24f65465fdbde02
# Processing image: HX1-Ro_GRAS_20210727185149_png_jpg.rf.8d6a6c048d5303d38146f86df76f444d
# Processing image: HX1-Ro_GRAS_20210727185149_png_jpg.rf.911b793196dc674dd69f493d3654df6f
# Processing image: HX1-Ro_GRAS_20210727185149_png_jpg.rf.bbbbc01e6834429feda88530993c1fbf
# Processing image: HX1-Ro_GRAS_20210727185149_png_jpg.rf.d7ee91a8d0cd1425b058a672d701ce06
# Processing image: HX1-Ro_GRAS_20210727185149_png_jpg.rf.e3dec2a43f802784e2cbdc42e86d7ab0
# Processing image: HX1-Ro_GRAS_20210727185149_png_jpg.rf.fe849a976ae209a3b8dde549d2f67cac
# Processing image: HX1-Ro_GRAS_20210730202228_png_jpg.rf.04338e95bf5a7ce733da7e7852bacd3f
# Processing image: HX1-Ro_GRAS_20210730202228_png_jpg.rf.340f9f9da4339c441d858bd9d4c310cb
# Processing image: HX1-Ro_GRAS_20210730202228_png_jpg.rf.76abc719c0a63f676398faeb57710362
# Processing image: HX1-Ro_GRAS_20210730202228_png_jpg.rf.969a429e0101547032d1aea2ad4460fd
# Processing image: HX1-Ro_GRAS_20210730202228_png_jpg.rf.a3c8521cf368fca90566bc62725f193e
# Processing image: HX1-Ro_GRAS_20210730202228_png_jpg.rf.be4f95105592b4c49ebde33c05f6a42f
# Processing image: HX1-Ro_GRAS_20210730202228_png_jpg.rf.d4c3a0dde53c76cc4fb32af617d1fbc0
# Processing image: HX1-Ro_GRAS_20210804233619_png_jpg.rf.04b50b5043b5caf37b91fdd0767fbf42
# Processing image: HX1-Ro_GRAS_20210804233619_png_jpg.rf.3a8d0abcd51e0a94ea8ac717c9b26488
# Processing image: HX1-Ro_GRAS_20210804233619_png_jpg.rf.c13146b6e50748889cbd655c44b35887
# Processing image: HX1-Ro_GRAS_20210808010805_png_jpg.rf.16d65b743fbe5d93af668ed993ad32e8
# Processing image: HX1-Ro_GRAS_20210808010805_png_jpg.rf.612e11c003ec421bc9ba4caef1d326f1
# Processing image: HX1-Ro_GRAS_20210808010805_png_jpg.rf.ea2587bd07277e107a331770eaec6a29
# Processing image: HX1-Ro_GRAS_20210808010805_png_jpg.rf.ea5041829bf16a9334be45578b09ba44
# Processing image: HX1-Ro_GRAS_20210808010805_png_jpg.rf.ec7e278ca146ea4999f7e42f6d3b8bad
# Processing image: HX1-Ro_GRAS_20210813045137_png_jpg.rf.029340da1284bc2219922aff0670eaf9
# Processing image: HX1-Ro_GRAS_20210813045137_png_jpg.rf.129fe64c37e418223d2c8b88d701c776
# Processing image: HX1-Ro_GRAS_20210813045137_png_jpg.rf.415d1732a9498eba13b00232b9a893e9
# Processing image: HX1-Ro_GRAS_20210813045137_png_jpg.rf.4c68644b297686322ecd85a00b5d0fb6
# Processing image: HX1-Ro_GRAS_20210813045137_png_jpg.rf.d05b397eeee71d81ed2bc0b95dd8c3aa
# Processing image: HX1-Ro_GRAS_20210815055305_png_jpg.rf.3fdf5773ebd95a4ab837611b7958b43a
# Processing image: HX1-Ro_GRAS_20210815055305_png_jpg.rf.7da9f0fa4886240c6f7c56c74b149c72
# Processing image: HX1-Ro_GRAS_20210815055305_png_jpg.rf.a38bcc4ce0163d9f90f4964e3efe3ea5
# Processing image: HX1-Ro_GRAS_20210818105921_png_jpg.rf.01a9fb3b9690bdcb61bcb01510e4fcdf
# Processing image: HX1-Ro_GRAS_20210818105921_png_jpg.rf.283a18b72c971a2cba892189e9d77c3d
# Processing image: HX1-Ro_GRAS_20210818105921_png_jpg.rf.702f599c2517076db727eda02538d659
# Processing image: HX1-Ro_GRAS_20210818105921_png_jpg.rf.869dc4676b3cfda6988bb17f6ba654e5
# Processing image: HX1-Ro_GRAS_20210818105921_png_jpg.rf.99a0c36f5ea8c8cb8474c1a7fbaee65c
# Processing image: HX1-Ro_GRAS_20210818105921_png_jpg.rf.e3ebdaf389e886ed824c546f530cbad5
# Processing image: HX1-Ro_GRAS_20210825150740_png_jpg.rf.573793a9afb5cfa7b2af778579d36c64
# Processing image: HX1-Ro_GRAS_20210825150740_png_jpg.rf.7987d83841f07c60c5303b182fb7f9cb
# Processing image: HX1-Ro_GRAS_20210825150740_png_jpg.rf.7c028deb593f08df786234fe53386f2b
# Processing image: HX1-Ro_GRAS_20210825150740_png_jpg.rf.a0c2cf52bc8a1878130d05e863f10280
# Processing image: HX1-Ro_GRAS_20210825150740_png_jpg.rf.c12af4a60ff9d95003f9bf6b07e09baf
# Processing image: HX1-Ro_GRAS_20210825150740_png_jpg.rf.c6f7648c009b07920282ffbef3925919
# Processing image: HX1-Ro_GRAS_20210825150740_png_jpg.rf.cf651ed43a990c030df63d0afceac0a0
# Processing image: HX1-Ro_GRAS_20210825150740_png_jpg.rf.e654e4b360b8fc62752dce4e78ec825a
# Processing image: HX1-Ro_GRAS_20210825150915_png_jpg.rf.068607e0f9b7ab67d4f66ed647ecef50
# Processing image: HX1-Ro_GRAS_20210825150915_png_jpg.rf.234e070e14ca650aca17decda1d1c05a
# Processing image: HX1-Ro_GRAS_20210825150915_png_jpg.rf.a62f72c5e3aac873df22fc42cc5d33d4
# Processing image: HX1-Ro_GRAS_20210825150915_png_jpg.rf.a8e38e43b97e80463d54107fb8b97e85
# Processing image: HX1-Ro_GRAS_20210825150915_png_jpg.rf.b9e3adefdd39f5ebd0f6b33cd59a3945
# Processing image: HX1-Ro_GRAS_20210825151033_png_jpg.rf.34d1011cb7c2f9ddcf7d95c0e28f097a
# Processing image: HX1-Ro_GRAS_20210825151033_png_jpg.rf.9df9d66c69f9dad4cca900357140ad54
# Processing image: HX1-Ro_GRAS_20210826154452_png_jpg.rf.46c5d75c008f1a097f182ab21ca04d03
# Processing image: HX1-Ro_GRAS_20210826154452_png_jpg.rf.62e7ba64d32fa8bcadf3e4f0cf019f4b
# Processing image: HX1-Ro_GRAS_20210826154452_png_jpg.rf.7b8a2c3e761eb22a1db003d7b7e0ea8d
# Processing image: HX1-Ro_GRAS_20210826154452_png_jpg.rf.86816fcb891144395c8f6cdd49326aaf
# Processing image: HX1-Ro_GRAS_20210826154452_png_jpg.rf.e94bf2c047b647e2aec785bb1a1c3bda
# Processing image: HX1-Ro_GRAS_20210826154452_png_jpg.rf.f06a036c27b98fe0557693fb3fc1c079
# Processing image: HX1-Ro_GRAS_20210826154610_png_jpg.rf.0163c269da2ece2ff9e7feb0bd3f57a8
# Processing image: HX1-Ro_GRAS_20210826154610_png_jpg.rf.8de17e5e90963abf52adff26283da023
# Processing image: HX1-Ro_GRAS_20210826154610_png_jpg.rf.cce401def00e302d989f55d2b7e50140
# Processing image: HX1-Ro_GRAS_20210826154610_png_jpg.rf.d58c5abdab479b135e59655c763bb5f5
# Processing image: HX1-Ro_GRAS_20210826154610_png_jpg.rf.d9578ab8834c4dd539ad30dcc45ad3ec
# Processing image: HX1-Ro_GRAS_20210826154610_png_jpg.rf.dac0d8fc8baf7c96d23c33355b814baf
# Processing image: HX1-Ro_GRAS_20210826154610_png_jpg.rf.e2a8a04dc2cdedaeaa4d68bbcc392a4a
# Processing image: HX1-Ro_GRAS_20210827170704_png_jpg.rf.0634a092caf9b6cd3a4c61a9316ee80a
# Processing image: HX1-Ro_GRAS_20210827170704_png_jpg.rf.1519c523ad9c0fd8fcdc8b84f6f09b5e
# Processing image: HX1-Ro_GRAS_20210827170704_png_jpg.rf.27a5da4bb9aa285e65a204819c2be671
# Processing image: HX1-Ro_GRAS_20210827170704_png_jpg.rf.40060466a3c98b7e93f7f4cabb9b3938
# Processing image: HX1-Ro_GRAS_20210827170704_png_jpg.rf.408ad0311b92c45eb09f6bbdbc6d2f66
# Processing image: HX1-Ro_GRAS_20210827170704_png_jpg.rf.4f0bed165cec1a9e252e1faba4bbb267
# Processing image: HX1-Ro_GRAS_20210827170704_png_jpg.rf.5945513dbcf556c50767f6be164d744c
# Processing image: HX1-Ro_GRAS_20210827170704_png_jpg.rf.7441493ce6104c6808b28a58a74768a2
# Processing image: HX1-Ro_GRAS_20210827170704_png_jpg.rf.92eeb0c7a70fb9a0e2f3916b02b65234
# Processing image: HX1-Ro_GRAS_20210827170704_png_jpg.rf.d89fcea708d5975192c6d4ab13f8d56a
# Processing image: HX1-Ro_GRAS_20210827170704_png_jpg.rf.fb2f329b1a7daefb2de28f880626545e
# Processing image: HX1-Ro_GRAS_20210827171149_png_jpg.rf.2d5b7b5aa9e4230e827e34c93145a1da
# Processing image: HX1-Ro_GRAS_20210827171149_png_jpg.rf.dcc63f5224af62dfa91e49c7e80eb7e1
# Processing image: HX1-Ro_GRAS_20210827171149_png_jpg.rf.f3f4e0492ed9b27b09a99a0afb617a06
# Processing image: HX1-Ro_GRAS_20210830181703_png_jpg.rf.0076fb072d3002109a32fa734f3a605f
# Processing image: HX1-Ro_GRAS_20210830181703_png_jpg.rf.056a305ce5dc492004266916ae19a956
# Processing image: HX1-Ro_GRAS_20210830181703_png_jpg.rf.0b1e8c4a2a9206a4f1ab045141e053ca
# Processing image: HX1-Ro_GRAS_20210830181703_png_jpg.rf.12edfd281c35b0432ae60fc2309d1a64
# Processing image: HX1-Ro_GRAS_20210830181703_png_jpg.rf.20402f7bd41eae32a5cd1fd41ecc0fa1
# Processing image: HX1-Ro_GRAS_20210830181703_png_jpg.rf.7385a592924a61dfe4818521dca0a324
# Processing image: HX1-Ro_GRAS_20210830181703_png_jpg.rf.f426603f25681b72caaceb77e76bce63
# Processing image: HX1-Ro_GRAS_20210903214007_png_jpg.rf.17aaa2e5a56a3045e5c71b94ea12801e
# Processing image: HX1-Ro_GRAS_20210903214007_png_jpg.rf.2123d4c30c5f37e2bab2f8fa4ef0ecea
# Processing image: HX1-Ro_GRAS_20210903214007_png_jpg.rf.2c94d19351dda3f45c0305d52d2ac71c
# Processing image: HX1-Ro_GRAS_20210903214007_png_jpg.rf.49565c066c8af95bfea691d23c0229ec
# Processing image: HX1-Ro_GRAS_20210903214007_png_jpg.rf.4eaa5d274dcda8b3449bd83dabc02539
# Processing image: HX1-Ro_GRAS_20210903214007_png_jpg.rf.74911b3ee8fa6fd8c83190c75670629b
# Processing image: HX1-Ro_GRAS_20210903214007_png_jpg.rf.894b01c3106a623a75c66f565aff8a80
# Processing image: HX1-Ro_GRAS_20210903214007_png_jpg.rf.985063d0bd2189f3bcaa0054bc0f06ed
# Processing image: HX1-Ro_GRAS_20210903214007_png_jpg.rf.efecb0ab0953688e9d11690cc57cc8bf
# Processing image: HX1-Ro_GRAS_20210903214007_png_jpg.rf.f260fea66028d1a8a5367c45bc78826f
# Processing image: HX1-Ro_GRAS_20210903214159_png_jpg.rf.0a3861efa334d670af593c57f9e83f20
# Processing image: HX1-Ro_GRAS_20210903214159_png_jpg.rf.111ca089d1bf72db97ee7fce8729b95c
# Processing image: HX1-Ro_GRAS_20210903214159_png_jpg.rf.21f29e4a475af476ccb3b06588845837
# Processing image: HX1-Ro_GRAS_20210903214159_png_jpg.rf.82fed96e6cce0d7e71c71c8278a67c1f
# Processing image: HX1-Ro_GRAS_20210903214159_png_jpg.rf.b14efa97d87965d854bf27512aa1d433
# Processing image: HX1-Ro_GRAS_20211029062443_png_jpg.rf.366abc07cc3d1de9c9d401986d539765
# Processing image: HX1-Ro_GRAS_20211029062443_png_jpg.rf.4a8595ed7373503f73530265f853740f
# Processing image: HX1-Ro_GRAS_20211029062443_png_jpg.rf.a98928e7658157654bbf2110256072a5
# Processing image: HX1-Ro_GRAS_20211029062443_png_jpg.rf.bda4f8e49371a8f9a17ffb64e3a3c32d
# Processing image: HX1-Ro_GRAS_20211029062443_png_jpg.rf.d09470500a335fb36c5bf8f74064b1f0
# Processing image: HX1-Ro_GRAS_20211029062443_png_jpg.rf.e47ace51e0ca70a3d9c782722799d86d
# Processing image: HX1-Ro_GRAS_20211029062443_png_jpg.rf.e78fcdfd99c732d13ea75abed68c7c3b
# Processing image: HX1-Ro_GRAS_20211029062443_png_jpg.rf.f8aa3a68cb84918b4f79fe53eed6f78b
# Processing image: HX1-Ro_GRAS_20211031080335_png_jpg.rf.3a4827868055ee42bca1eb2970634dc8
# Processing image: HX1-Ro_GRAS_20211031080335_png_jpg.rf.4bc129297f02953b2cc2447a011348b5
# Processing image: HX1-Ro_GRAS_20211031080335_png_jpg.rf.5f39a319bf0c72bbf960e9b5f6cb5366
# Processing image: HX1-Ro_GRAS_20211031080335_png_jpg.rf.76e3b5e918d86661548658148d58535b
# Processing image: HX1-Ro_GRAS_20211031080335_png_jpg.rf.e3c3a3d819e029b76c7e48177f0483b7
# Processing image: HX1-Ro_GRAS_20211031080335_png_jpg.rf.f9fe90f99026af54d05f57656ae1fcdd
# Processing image: HX1-Ro_GRAS_20211031080510_png_jpg.rf.35244958d82d9db2e6b9b26c26223c66
# Processing image: HX1-Ro_GRAS_20211031080510_png_jpg.rf.3b37bbeb48e21afea06be50bdd133dc4
# Processing image: HX1-Ro_GRAS_20211031080510_png_jpg.rf.431ce51ea1f7544bdf549cd9ffafff56
# Processing image: HX1-Ro_GRAS_20211031080510_png_jpg.rf.5d2af015f22e517f39713c8119acd9ba
# Processing image: HX1-Ro_GRAS_20211031080510_png_jpg.rf.7874143c5e61de8bff333f5b3382ed32
# Processing image: HX1-Ro_GRAS_20211031080510_png_jpg.rf.9753eb3ff46563d9214995b78677737f
# Processing image: HX1-Ro_GRAS_20211031080510_png_jpg.rf.ac6d82db1cfe0833ff280873372bc42c
# Processing image: HX1-Ro_GRAS_20211103103536_png_jpg.rf.10f52d5e1e94f091ceeb6ae741855710
# Processing image: HX1-Ro_GRAS_20211103103536_png_jpg.rf.604f383332b248d2133fa24f1975aa7f
# Processing image: HX1-Ro_GRAS_20211103103536_png_jpg.rf.75907376e300afa0c6ad0680f7db255d
# Processing image: HX1-Ro_GRAS_20211103103536_png_jpg.rf.ad301f2c4dc4aa6916ba2a7efd65cae4
# Processing image: HX1-Ro_GRAS_20211103103536_png_jpg.rf.f1200e4ab5f46b0c13858c31690616a6
# Processing image: HX1-Ro_GRAS_20211103103536_png_jpg.rf.fb5ef64e1745a28ce733035335a6270b
# Processing image: HX1-Ro_GRAS_20211104114033_png_jpg.rf.443cff3d75114ec40bd5551b0ca39727
# Processing image: HX1-Ro_GRAS_20211104114033_png_jpg.rf.463385c53b6eb97ebd41379732f49e05
# Processing image: HX1-Ro_GRAS_20211104114033_png_jpg.rf.624dd14a01318e4a77f9db57e99fa09a
# Processing image: HX1-Ro_GRAS_20211104114033_png_jpg.rf.9141db38791c8efa5f5894500689ef72
# Processing image: HX1-Ro_GRAS_20211106123130_png_jpg.rf.06506b02221e23a659aebbfa9a42eaf9
# Processing image: HX1-Ro_GRAS_20211106123130_png_jpg.rf.5566458c6379ed8d1bc005d25d929891
# Processing image: HX1-Ro_GRAS_20211106123130_png_jpg.rf.703466dc8c27557e292b42f6dfa2d016
# Processing image: HX1-Ro_GRAS_20211106123130_png_jpg.rf.78e9700cb7ba94820fd212664a82fd75
# Processing image: HX1-Ro_GRAS_20211106123130_png_jpg.rf.b5eb96c1af4e3f1de64bfea8ab0b0085
# Processing image: HX1-Ro_GRAS_20211106123130_png_jpg.rf.bf0d0e6c023e58c17ed49ff25ac7e04b
# Processing image: HX1-Ro_GRAS_20211106123130_png_jpg.rf.f641155cabe5252f4ff67e57a8009dfd
# Processing image: HX1-Ro_GRAS_20211204054014_png_jpg.rf.1230d8c8c156027e24241a3f83d275fb
# Processing image: HX1-Ro_GRAS_20211204054014_png_jpg.rf.3eb92590fd9318d8c0ea6c32b213cda6
# Processing image: HX1-Ro_GRAS_20211204054014_png_jpg.rf.c779e9515ebb782ea9dbdb99dd7fcc83
# Processing image: HX1-Ro_GRAS_20211204054014_png_jpg.rf.df1e154537deefce591759e6fd71070f
# Processing image: HX1-Ro_GRAS_20211204054014_png_jpg.rf.f85dc3bd3dd5c201f6a4c7f03dc3d702
# Processing image: HX1-Ro_GRAS_20220112071835_png_jpg.rf.2f6e68de37277bf8780add43bc28c24d
# Processing image: HX1-Ro_GRAS_20220112071835_png_jpg.rf.90f902897faadbe116a24af745f7ccbf
# Processing image: HX1-Ro_GRAS_20220112071835_png_jpg.rf.a54817de70ce7a7bc340503f69a1906d
# Processing image: HX1-Ro_GRAS_20220112071835_png_jpg.rf.bd48a004778a3e1adac0eca421573fbe
# Processing image: HX1-Ro_GRAS_20220112071835_png_jpg.rf.dad15dc6bcdef432860ff11da5ecb09a
# Processing image: HX1-Ro_GRAS_20220112071835_png_jpg.rf.e3a47b80dd0026c09afb690ab06f44b3
# Processing image: HX1-Ro_GRAS_20220117102938_png_jpg.rf.1d8cba54838a2267a5ec9998b9fa9f93
# Processing image: HX1-Ro_GRAS_20220117102938_png_jpg.rf.5ea1a5668a5bb862f8659899604fed15
# Processing image: HX1-Ro_GRAS_20220117102938_png_jpg.rf.60db3ceceda9792fd76d353fca93c2fc
# Processing image: HX1-Ro_GRAS_20220117102938_png_jpg.rf.8a11bef850b47ff127610c3298f51326
# Processing image: HX1-Ro_GRAS_20220117102938_png_jpg.rf.8dad6e950b7662f06b97e4ae51da17f6
# Processing image: HX1-Ro_GRAS_20220117102938_png_jpg.rf.cc8ec3e0c2a9b55abe8675702962669a
# Processing image: HX1-Ro_GRAS_20220117102938_png_jpg.rf.e906d79f08377bb73ac5177a14e8bb3c
# Processing image: HX1-Ro_GRAS_20220117102938_png_jpg.rf.eeca2538c3c911e9131bbe696972c486
# Processing image: HX1-Ro_GRAS_20220117103056_png_jpg.rf.138bd02784d3cc85a707db94e6e73f73
# Processing image: HX1-Ro_GRAS_20220117103056_png_jpg.rf.345ecc1cce144cdb05074657d006cb85
# Processing image: HX1-Ro_GRAS_20220117103056_png_jpg.rf.3c20825d6d696f171e48941cf339f946
# Processing image: HX1-Ro_GRAS_20220117103056_png_jpg.rf.6b41c29871db2389bfd544d1a4bb0c48
# Processing image: HX1-Ro_GRAS_20220117103056_png_jpg.rf.9e39aee71065436cbf83552ab94b5959
# Processing image: HX1-Ro_GRAS_20220117103056_png_jpg.rf.ab9ac1aa38a9a955f2d092135e555478
# Processing image: HX1-Ro_GRAS_20220117103056_png_jpg.rf.cb307d95c31892bb9b570be8ec14bfb1
# Processing image: HX1-Ro_GRAS_20220117103056_png_jpg.rf.e664b2f6cda60c71654fc582c1de9937
# Processing image: HX1-Ro_GRAS_20220117103406_png_jpg.rf.3c05209a467ac7e04326a067b1ef7f9e
# Processing image: HX1-Ro_GRAS_20220117103406_png_jpg.rf.63863fe147b9446366409b7d785ec2aa
# Processing image: HX1-Ro_GRAS_20220117103406_png_jpg.rf.a5d243a11aae84dbeb1f584ba3e3029e
# Processing image: HX1-Ro_GRAS_20220117103406_png_jpg.rf.aa97d1092e94728b1232f2a974f4f5c4
# Processing image: HX1-Ro_GRAS_20220129175005_png_jpg.rf.38f423993a28e720a3b76b2e6a09e886
# Processing image: HX1-Ro_GRAS_20220129175005_png_jpg.rf.3ca05548cf3d8bce6b539725b30c2234
# Processing image: HX1-Ro_GRAS_20220129175005_png_jpg.rf.dd7fc20b21e15df06ed464b641d59ae7
# Processing image: HX1-Ro_GRAS_20220129175005_png_jpg.rf.dfb9a6fd348c27adb50789d29ab03290
# Processing image: HX1-Ro_GRAS_20220129175005_png_jpg.rf.e40e388997fcd72ad7e69b5c680857b2
# Processing image: HX1-Ro_GRAS_20220129175005_png_jpg.rf.e5d584e417e34c93a1137f74e8a6a16c
# Processing image: HX1-Ro_GRAS_20220217054014_png_jpg.rf.03abb579314797eb1830b73183e5eb8a
# Processing image: HX1-Ro_GRAS_20220217054014_png_jpg.rf.2895aa74adf2648d52fd69d7110e86de
# Processing image: HX1-Ro_GRAS_20220217054014_png_jpg.rf.3b73584c1aa7202fca4659f47e08aaec
# Processing image: HX1-Ro_GRAS_20220217054014_png_jpg.rf.4115f6789e84509685d6b67190109e27
# Processing image: HX1-Ro_GRAS_20220217054014_png_jpg.rf.6a566898e1d066d040a59c33eaa675ac
# Processing image: HX1-Ro_GRAS_20220217054014_png_jpg.rf.743dca055c3c33b624e4c9567d91b030
# Processing image: HX1-Ro_GRAS_20220217054014_png_jpg.rf.b732acbb8502bf9fc30a0de142a0b2a0
# Processing image: HX1-Ro_GRAS_20220217054014_png_jpg.rf.b90f58fb3f64cebc10de1565dd56f669
# Processing image: HX1-Ro_GRAS_20220219065853_png_jpg.rf.4172ccfe0b81e7fdfcc82e3f1306492c
# Processing image: HX1-Ro_GRAS_20220219065853_png_jpg.rf.7a9faa86141a003c7931c73b7061fdfb
# Processing image: HX1-Ro_GRAS_20220219065853_png_jpg.rf.8a0768515ac1fa1d8b8aeceb86fb2110
# Processing image: HX1-Ro_GRAS_20220219065853_png_jpg.rf.ad1debb57e3f04b08fa74a8a30fb1c83
# Processing image: HX1-Ro_GRAS_20220219065853_png_jpg.rf.b1d1cfd688807ec00d1a6fb81a98b2b3
# Processing image: HX1-Ro_GRAS_20220219065853_png_jpg.rf.be2dcff87ca243aa3e78a763b1ad344a
# Processing image: HX1-Ro_GRAS_20220220081831_png_jpg.rf.1ce200e8d6c554b0bb355a75893e1dce
# Processing image: HX1-Ro_GRAS_20220220081831_png_jpg.rf.4204852bbb1368cb483a9cf6c3ce5781
# Processing image: HX1-Ro_GRAS_20220220081831_png_jpg.rf.77df405a931b32f562466f63345d80f8
# Processing image: HX1-Ro_GRAS_20220220081831_png_jpg.rf.7862e1279718d129af804b267efb769e
# Processing image: HX1-Ro_GRAS_20220220081831_png_jpg.rf.a072329017cd3e81cb5fc491f6b1fd74
# Processing image: HX1-Ro_GRAS_20220220081831_png_jpg.rf.ecacb893e2f8b69e9960c5e32a264f1b
# Processing image: HX1-Ro_GRAS_20220220081831_png_jpg.rf.ef8d0d63ec0fb1e3e0f80cd628e12ae7
# Processing image: HX1-Ro_GRAS_20220220081831_png_jpg.rf.f74630d78cf3778aca7eeb830cf9cace
# Processing image: HX1-Ro_GRAS_20220220081949_png_jpg.rf.1f4531bf84411edab61af84feaeca36e
# Processing image: HX1-Ro_GRAS_20220220081949_png_jpg.rf.296817a24d7feab7577125d838414321
# Processing image: HX1-Ro_GRAS_20220220081949_png_jpg.rf.29f3aacf63e0ec3b409d72af3c298dda
# Processing image: HX1-Ro_GRAS_20220220081949_png_jpg.rf.35a31e2d7705203a99059f561790add6
# Processing image: HX1-Ro_GRAS_20220220081949_png_jpg.rf.39396997d3784c610040de84fe5640e0
# Processing image: HX1-Ro_GRAS_20220220081949_png_jpg.rf.60edae3150365cc98ffd988e3e5e4c15
# Processing image: HX1-Ro_GRAS_20220220081949_png_jpg.rf.ba0f6a6aacef09f57f18f2982e0c2d18

# %%
plot_bboxes(img_list[0], box_list[0])

# %%
#YOLO algorithm
# Load the model.
model = YOLO('yolov8n.pt')
 
# Training.
results = model.train(
    data='./images/mars_rover/data.yaml',
    imgsz=640,
    epochs=1000,
    batch=8,
    name='yolov8n_rocks')
# Out:
# Ultralytics YOLOv8.0.105 🚀 Python-3.10.6 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12044MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# yolo/engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=./images/mars_rover/data.yaml, epochs=1000, patience=50, batch=8, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=yolov8n_rocks, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/detect/yolov8n_rocks2
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py in __init__(self, cfg, overrides, _callbacks)
#     122             elif self.args.data.endswith('.yaml') or self.args.task in ('detect', 'segment'):
# --> 123                 self.data = check_det_dataset(self.args.data)
#     124                 if 'yaml_file' in self.data:
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/data/utils.py in check_det_dataset(dataset, autodownload)
#     194     """Download, check and/or unzip dataset if not found locally."""
# --> 195     data = check_file(dataset)
#     196
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/utils/checks.py in check_file(file, suffix, download, hard)
#     291         if not files and hard:
# --> 292             raise FileNotFoundError(f"'{file}' does not exist")
#     293         elif len(files) > 1 and hard:
#
# FileNotFoundError: './images/mars_rover/data.yaml' does not exist
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_186201/3733053903.py in <module>
#       4
#       5 # Training.
# ----> 6 results = model.train(
#       7     data='./images/mars_rover/data.yaml',
#       8     imgsz=640,
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py in train(self, **kwargs)
#     364             overrides['resume'] = self.ckpt_path
#     365         self.task = overrides.get('task') or self.task
# --> 366         self.trainer = TASK_MAP[self.task][1](overrides=overrides, _callbacks=self.callbacks)
#     367         if not overrides.get('resume'):  # manually set model only if not resuming
#     368             self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py in __init__(self, cfg, overrides, _callbacks)
#     125                     self.args.data = self.data['yaml_file']  # for validating 'yolo train data=url.zip' usage
#     126         except Exception as e:
# --> 127             raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     128
#     129         self.trainset, self.testset = self.get_dataset(self.data)
#
# RuntimeError: Dataset 'images/mars_rover/data.yaml' error ❌ './images/mars_rover/data.yaml' does not exist

# %%
img_dir = './images/mars_rover/test/images'
img_list = os.listdir(img_dir)
images = []
for img in img_list:
    images.append(mpimg.imread(os.path.join(img_dir,img)))

resultsp = model.predict(images)
bboxes = [[float(i) for i in item[0:-2]] for item in resultsp[0].boxes.data]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_186201/200863792.py in <module>
#       1 img_dir = './images/mars_rover/test/images'
# ----> 2 img_list = os.listdir(img_dir)
#       3 images = []
#       4 for img in img_list:
#       5     images.append(mpimg.imread(os.path.join(img_dir,img)))
#
# FileNotFoundError: [Errno 2] No such file or directory: './images/mars_rover/test/images'

# %%
def box_label(image, box, label='', color=(128, 128, 128), txt_color=(255, 255, 255)):
    lw = max(round(sum(image.shape) / 2 * 0.003), 2)
    p1, p2 = (int(box[0]), int(box[1])), (int(box[2]), int(box[3]))
    cv2.rectangle(image, p1, p2, color, thickness=lw, lineType=cv2.LINE_AA)
    if label:
        tf = max(lw - 1, 1)  # font thickness
        w, h = cv2.getTextSize(label, 0, fontScale=lw / 3, thickness=tf)[0]  # text width, height
        outside = p1[1] - h >= 3
        p2 = p1[0] + w, p1[1] - h - 3 if outside else p1[1] + h + 3
        cv2.rectangle(image, p1, p2, color, -1, cv2.LINE_AA)  # filled
        cv2.putText(image,
                    label, (p1[0], p1[1] - 2 if outside else p1[1] + h + 2),
                    0,
                    lw / 3,
                    txt_color,
                    thickness=tf,
                    lineType=cv2.LINE_AA)

# %%
def plot_bboxes(image, boxes, labels=[], colors=[], score=True, conf=None):
    #Define COCO Labels
    if labels == []:
        labels = {0:'rover', 1:'rock'}
    #Define colors
    if colors == []:
    #colors = [(6, 112, 83), (253, 246, 160), (40, 132, 70), (205, 97, 162), (149, 196, 30), (106, 19, 161), (127, 175, 225), (115, 133, 176), (83, 156, 8), (182, 29, 77), (180, 11, 251), (31, 12, 123), (23, 6, 115), (167, 34, 31), (176, 216, 69), (110, 229, 222), (72, 183, 159), (90, 168, 209), (195, 4, 209), (135, 236, 21), (62, 209, 199), (87, 1, 70), (75, 40, 168), (121, 90, 126), (11, 86, 86), (40, 218, 53), (234, 76, 20), (129, 174, 192), (13, 18, 254), (45, 183, 149), (77, 234, 120), (182, 83, 207), (172, 138, 252), (201, 7, 159), (147, 240, 17), (134, 19, 233), (202, 61, 206), (177, 253, 26), (10, 139, 17), (130, 148, 106), (174, 197, 128), (106, 59, 168), (124, 180, 83), (78, 169, 4), (26, 79, 176), (185, 149, 150), (165, 253, 206), (220, 87, 0), (72, 22, 226), (64, 174, 4), (245, 131, 96), (35, 217, 142), (89, 86, 32), (80, 56, 196), (222, 136, 159), (145, 6, 219), (143, 132, 162), (175, 97, 221), (72, 3, 79), (196, 184, 237), (18, 210, 116), (8, 185, 81), (99, 181, 254), (9, 127, 123), (140, 94, 215), (39, 229, 121), (230, 51, 96), (84, 225, 33), (218, 202, 139), (129, 223, 182), (167, 46, 157), (15, 252, 5), (128, 103, 203), (197, 223, 199), (19, 238, 181), (64, 142, 167), (12, 203, 242), (69, 21, 41), (177, 184, 2), (35, 97, 56), (241, 22, 161)]
        colors = [(89, 161, 197),(67, 161, 255)]
    #plot each boxes
    for box in boxes:
        #add score in label if score=True
        if score :
            label = labels[int(box[-1])+1] + " " + str(round(100 * float(box[-2]),1)) + "%"
        else :
            label = labels[int(box[-1])+1]
        #filter every box under conf threshold if conf threshold setted
        if conf :
            if box[-2] > conf:
                color = colors[int(box[-1])]
                box_label(image, box, label, color)
        else:
            color = colors[int(box[-1])]
            box_label(image, box, label, color)

        plt.imshow(image) #if used in Python

# %%
idx = 4
plot_bboxes(images[idx], resultsp[idx].boxes.data, conf=0.25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_186201/4223388092.py in <module>
#       1 idx = 4
# ----> 2 plot_bboxes(images[idx], resultsp[idx].boxes.data, conf=0.25)
#
# NameError: name 'images' is not defined
